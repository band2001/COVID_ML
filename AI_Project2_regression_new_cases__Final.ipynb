# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
pd.options.display.max_rows = 1000

# %%
# Preprocessing Input data
data = pd.read_csv('covid_data.csv', low_memory = False)

# %%
pd.set_option('display.max_columns', None)
data.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.122                  0.122
# 1                    0.122                  0.000
# 2                    0.122                  0.000
# 3                    0.122                  0.000
# 4                    0.122                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 0                                 NaN          NaN        NaN
# 1                                 NaN          NaN        NaN
# 2                                 NaN          NaN        NaN
# 3                                 NaN          NaN        NaN
# 4                                 NaN          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                              NaN            NaN             NaN         NaN
# 1                              NaN            NaN             NaN         NaN
# 2                              NaN            NaN             NaN         NaN
# 3                              NaN            NaN             NaN         NaN
# 4                              NaN            NaN             NaN         NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
#
#    total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# 0             NaN               NaN                        NaN
# 1             NaN               NaN                        NaN
# 2             NaN               NaN                        NaN
# 3             NaN               NaN                        NaN
# 4             NaN               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
#
#    new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
#
#    new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 0                                         NaN              8.33
# 1                                         NaN              8.33
# 2                                         NaN              8.33
# 3                                         NaN              8.33
# 4                                         NaN              8.33
#
#    population_density  median_age  aged_65_older  aged_70_older  \
# 0              54.422        18.6          2.581          1.337
# 1              54.422        18.6          2.581          1.337
# 2              54.422        18.6          2.581          1.337
# 3              54.422        18.6          2.581          1.337
# 4              54.422        18.6          2.581          1.337
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    population  excess_mortality_cumulative_absolute  \
# 0  41128772.0                                   NaN
# 1  41128772.0                                   NaN
# 2  41128772.0                                   NaN
# 3  41128772.0                                   NaN
# 4  41128772.0                                   NaN
#
#    excess_mortality_cumulative  excess_mortality  \
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                          NaN               NaN
#
#    excess_mortality_cumulative_per_million
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN

# %%
data.corr()
# Out:
# /var/folders/3z/92v05ntj4hnc_xkhx758n9r40000gn/T/ipykernel_34707/2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                             total_cases  new_cases  \
# total_cases                                    1.000000   0.671281
# new_cases                                      0.671281   1.000000
# new_cases_smoothed                             0.694447   0.972716
# total_deaths                                   0.936471   0.705354
# new_deaths                                     0.437488   0.645232
# new_deaths_smoothed                            0.452197   0.632060
# total_cases_per_million                        0.096539   0.050278
# new_cases_per_million                          0.011118   0.055671
# new_cases_smoothed_per_million                 0.019262   0.076962
# total_deaths_per_million                       0.117472   0.071847
# new_deaths_per_million                        -0.002134   0.027721
# new_deaths_smoothed_per_million               -0.002758   0.038517
# reproduction_rate                              0.015249   0.034652
# icu_patients                                   0.427364   0.566308
# icu_patients_per_million                      -0.009693   0.141977
# hosp_patients                                  0.543343   0.708142
# hosp_patients_per_million                     -0.004175   0.124544
# weekly_icu_admissions                          0.180461   0.371483
# weekly_icu_admissions_per_million             -0.086610   0.002864
# weekly_hosp_admissions                         0.534580   0.663834
# weekly_hosp_admissions_per_million            -0.014550   0.052044
# total_tests                                    0.857953   0.446090
# new_tests                                      0.577009   0.546949
# total_tests_per_thousand                       0.095714   0.070955
# new_tests_per_thousand                         0.011806   0.069460
# new_tests_smoothed                             0.088549   0.082976
# new_tests_smoothed_per_thousand                0.017699   0.075642
# positive_rate                                  0.044091   0.177313
# tests_per_case                                -0.017761  -0.015176
# total_vaccinations                             0.825825   0.548923
# people_vaccinated                              0.825345   0.566399
# people_fully_vaccinated                        0.828205   0.555657
# total_boosters                                 0.837732   0.458893
# new_vaccinations                               0.441283   0.489268
# new_vaccinations_smoothed                      0.475606   0.509483
# total_vaccinations_per_hundred                 0.150732   0.076909
# people_vaccinated_per_hundred                  0.146104   0.070801
# people_fully_vaccinated_per_hundred            0.136012   0.067100
# total_boosters_per_hundred                     0.029545  -0.021554
# new_vaccinations_smoothed_per_million         -0.018182   0.020798
# new_people_vaccinated_smoothed                 0.369438   0.386417
# new_people_vaccinated_smoothed_per_hundred    -0.036961  -0.017362
# stringency_index                              -0.099538   0.017859
# population_density                            -0.016361  -0.014667
# median_age                                     0.040162   0.045548
# aged_65_older                                  0.039862   0.046743
# aged_70_older                                  0.038303   0.046336
# gdp_per_capita                                 0.017034   0.020657
# extreme_poverty                               -0.036995  -0.035473
# cardiovasc_death_rate                         -0.042432  -0.045700
# diabetes_prevalence                            0.002806  -0.000621
# female_smokers                                 0.002295   0.006337
# male_smokers                                  -0.002528   0.001461
# handwashing_facilities                         0.032736   0.030484
# hospital_beds_per_thousand                     0.007190   0.020700
# life_expectancy                                0.020333   0.025256
# human_development_index                        0.044100   0.046879
# population                                     0.614839   0.543217
# excess_mortality_cumulative_absolute           0.753939   0.327804
# excess_mortality_cumulative                    0.093883   0.049482
# excess_mortality                              -0.022547   0.083522
# excess_mortality_cumulative_per_million        0.189320   0.054802
#
#                                             new_cases_smoothed  total_deaths  \
# total_cases                                           0.694447      0.936471
# new_cases                                             0.972716      0.705354
# new_cases_smoothed                                    1.000000      0.725595
# total_deaths                                          0.725595      1.000000
# new_deaths                                            0.639532      0.605267
# new_deaths_smoothed                                   0.651794      0.624088
# total_cases_per_million                               0.052823      0.043576
# new_cases_per_million                                 0.046911      0.002817
# new_cases_smoothed_per_million                        0.079204      0.004377
# total_deaths_per_million                              0.074411      0.127753
# new_deaths_per_million                                0.024378      0.005605
# new_deaths_smoothed_per_million                       0.040885      0.010745
# reproduction_rate                                     0.029602      0.020758
# icu_patients                                          0.620019      0.572833
# icu_patients_per_million                              0.158048      0.058951
# hosp_patients                                         0.777611      0.633431
# hosp_patients_per_million                             0.140638      0.007659
# weekly_icu_admissions                                 0.427288      0.333533
# weekly_icu_admissions_per_million                     0.008202     -0.068638
# weekly_hosp_admissions                                0.731456      0.647501
# weekly_hosp_admissions_per_million                    0.060793     -0.002721
# total_tests                                           0.473537      0.773960
# new_tests                                             0.555368      0.583425
# total_tests_per_thousand                              0.075653      0.030820
# new_tests_per_thousand                                0.065636     -0.008799
# new_tests_smoothed                                    0.087318      0.082783
# new_tests_smoothed_per_thousand                       0.077916     -0.008990
# positive_rate                                         0.190999      0.029824
# tests_per_case                                       -0.015997     -0.018476
# total_vaccinations                                    0.565814      0.831558
# people_vaccinated                                     0.583026      0.853168
# people_fully_vaccinated                               0.572416      0.836030
# total_boosters                                        0.478058      0.749623
# new_vaccinations                                      0.485940      0.608914
# new_vaccinations_smoothed                             0.517919      0.637719
# total_vaccinations_per_hundred                        0.079649      0.094357
# people_vaccinated_per_hundred                         0.072849      0.104888
# people_fully_vaccinated_per_hundred                   0.068959      0.081868
# total_boosters_per_hundred                           -0.019917     -0.072804
# new_vaccinations_smoothed_per_million                 0.019853      0.015922
# new_people_vaccinated_smoothed                        0.392629      0.536702
# new_people_vaccinated_smoothed_per_hundred           -0.018183     -0.009995
# stringency_index                                      0.017451     -0.039652
# population_density                                   -0.015012     -0.020222
# median_age                                            0.046449      0.034048
# aged_65_older                                         0.047625      0.029642
# aged_70_older                                         0.047191      0.027043
# gdp_per_capita                                        0.021031      0.006654
# extreme_poverty                                      -0.036229     -0.044505
# cardiovasc_death_rate                                -0.046634     -0.038895
# diabetes_prevalence                                  -0.000529      0.012228
# female_smokers                                        0.006393     -0.007050
# male_smokers                                          0.001512     -0.002020
# handwashing_facilities                                0.031089      0.042935
# hospital_beds_per_thousand                            0.021028     -0.006477
# life_expectancy                                       0.025714      0.016506
# human_development_index                               0.047844      0.039991
# population                                            0.557834      0.712860
# excess_mortality_cumulative_absolute                  0.426156      0.926142
# excess_mortality_cumulative                           0.040194      0.280627
# excess_mortality                                      0.064064      0.016416
# excess_mortality_cumulative_per_million               0.071633      0.303454
#
#                                             new_deaths  new_deaths_smoothed  \
# total_cases                                   0.437488             0.452197
# new_cases                                     0.645232             0.632060
# new_cases_smoothed                            0.639532             0.651794
# total_deaths                                  0.605267             0.624088
# new_deaths                                    1.000000             0.976632
# new_deaths_smoothed                           0.976632             1.000000
# total_cases_per_million                      -0.032253            -0.032708
# new_cases_per_million                         0.008870             0.005081
# new_cases_smoothed_per_million                0.008945             0.008606
# total_deaths_per_million                      0.029044             0.030630
# new_deaths_per_million                        0.065524             0.056646
# new_deaths_smoothed_per_million               0.094107             0.096416
# reproduction_rate                             0.027227             0.025673
# icu_patients                                  0.846498             0.910996
# icu_patients_per_million                      0.304960             0.328663
# hosp_patients                                 0.848142             0.908403
# hosp_patients_per_million                     0.198440             0.211187
# weekly_icu_admissions                         0.611968             0.708906
# weekly_icu_admissions_per_million             0.093181             0.136157
# weekly_hosp_admissions                        0.810465             0.870311
# weekly_hosp_admissions_per_million            0.062999             0.072936
# total_tests                                   0.363663             0.390923
# new_tests                                     0.508835             0.510354
# total_tests_per_thousand                     -0.033620            -0.035157
# new_tests_per_thousand                       -0.014832            -0.020181
# new_tests_smoothed                            0.068595             0.072449
# new_tests_smoothed_per_thousand              -0.012627            -0.014117
# positive_rate                                 0.123928             0.125146
# tests_per_case                               -0.019618            -0.020927
# total_vaccinations                            0.343123             0.355147
# people_vaccinated                             0.384269             0.397512
# people_fully_vaccinated                       0.336009             0.347761
# total_boosters                                0.168908             0.176280
# new_vaccinations                              0.642330             0.646598
# new_vaccinations_smoothed                     0.646697             0.665648
# total_vaccinations_per_hundred               -0.109427            -0.111391
# people_vaccinated_per_hundred                -0.120281            -0.122239
# people_fully_vaccinated_per_hundred          -0.136106            -0.139060
# total_boosters_per_hundred                   -0.196569            -0.201691
# new_vaccinations_smoothed_per_million         0.041147             0.043091
# new_people_vaccinated_smoothed                0.630735             0.648203
# new_people_vaccinated_smoothed_per_hundred    0.031963             0.033686
# stringency_index                              0.144199             0.153454
# population_density                           -0.019818            -0.020267
# median_age                                    0.035908             0.036679
# aged_65_older                                 0.031615             0.032282
# aged_70_older                                 0.029085             0.029688
# gdp_per_capita                                0.007713             0.007853
# extreme_poverty                              -0.044412            -0.045392
# cardiovasc_death_rate                        -0.036153            -0.036885
# diabetes_prevalence                           0.011840             0.012171
# female_smokers                               -0.005342            -0.005444
# male_smokers                                  0.002361             0.002481
# handwashing_facilities                        0.042830             0.043667
# hospital_beds_per_thousand                   -0.001703            -0.001713
# life_expectancy                               0.016642             0.016982
# human_development_index                       0.040683             0.041568
# population                                    0.685255             0.702537
# excess_mortality_cumulative_absolute          0.345597             0.540006
# excess_mortality_cumulative                   0.224177             0.203424
# excess_mortality                              0.353579             0.286932
# excess_mortality_cumulative_per_million       0.067323             0.091433
#
#                                             total_cases_per_million  \
# total_cases                                                0.096539
# new_cases                                                  0.050278
# new_cases_smoothed                                         0.052823
# total_deaths                                               0.043576
# new_deaths                                                -0.032253
# new_deaths_smoothed                                       -0.032708
# total_cases_per_million                                    1.000000
# new_cases_per_million                                      0.177797
# new_cases_smoothed_per_million                             0.310826
# total_deaths_per_million                                   0.598654
# new_deaths_per_million                                     0.049797
# new_deaths_smoothed_per_million                            0.083836
# reproduction_rate                                         -0.035956
# icu_patients                                              -0.060391
# icu_patients_per_million                                  -0.127097
# hosp_patients                                             -0.003563
# hosp_patients_per_million                                  0.010412
# weekly_icu_admissions                                     -0.158304
# weekly_icu_admissions_per_million                         -0.124784
# weekly_hosp_admissions                                    -0.038447
# weekly_hosp_admissions_per_million                        -0.031443
# total_tests                                                0.202881
# new_tests                                                  0.093058
# total_tests_per_thousand                                   0.587226
# new_tests_per_thousand                                     0.258976
# new_tests_smoothed                                        -0.032010
# new_tests_smoothed_per_thousand                            0.292134
# positive_rate                                              0.288126
# tests_per_case                                            -0.046147
# total_vaccinations                                        -0.072145
# people_vaccinated                                         -0.076722
# people_fully_vaccinated                                   -0.070867
# total_boosters                                            -0.071494
# new_vaccinations                                          -0.151256
# new_vaccinations_smoothed                                 -0.070405
# total_vaccinations_per_hundred                             0.606359
# people_vaccinated_per_hundred                              0.534104
# people_fully_vaccinated_per_hundred                        0.562711
# total_boosters_per_hundred                                 0.658567
# new_vaccinations_smoothed_per_million                     -0.112349
# new_people_vaccinated_smoothed                            -0.074477
# new_people_vaccinated_smoothed_per_hundred                -0.173160
# stringency_index                                          -0.400432
# population_density                                         0.028717
# median_age                                                 0.418985
# aged_65_older                                              0.404328
# aged_70_older                                              0.404469
# gdp_per_capita                                             0.316166
# extreme_poverty                                           -0.314781
# cardiovasc_death_rate                                     -0.215464
# diabetes_prevalence                                        0.050283
# female_smokers                                             0.369268
# male_smokers                                               0.059008
# handwashing_facilities                                     0.401455
# hospital_beds_per_thousand                                 0.243527
# life_expectancy                                            0.370353
# human_development_index                                    0.435825
# population                                                -0.060534
# excess_mortality_cumulative_absolute                       0.059845
# excess_mortality_cumulative                                0.078718
# excess_mortality                                          -0.055450
# excess_mortality_cumulative_per_million                    0.375051
#
#                                             new_cases_per_million  \
# total_cases                                              0.011118
# new_cases                                                0.055671
# new_cases_smoothed                                       0.046911
# total_deaths                                             0.002817
# new_deaths                                               0.008870
# new_deaths_smoothed                                      0.005081
# total_cases_per_million                                  0.177797
# new_cases_per_million                                    1.000000
# new_cases_smoothed_per_million                           0.600007
# total_deaths_per_million                                 0.116564
# new_deaths_per_million                                   0.184577
# new_deaths_smoothed_per_million                          0.169499
# reproduction_rate                                        0.099997
# icu_patients                                             0.035675
# icu_patients_per_million                                 0.143899
# hosp_patients                                            0.061680
# hosp_patients_per_million                                0.244110
# weekly_icu_admissions                                    0.149225
# weekly_icu_admissions_per_million                        0.015018
# weekly_hosp_admissions                                   0.085023
# weekly_hosp_admissions_per_million                       0.068597
# total_tests                                              0.072396
# new_tests                                                0.114869
# total_tests_per_thousand                                 0.345291
# new_tests_per_thousand                                   0.338811
# new_tests_smoothed                                      -0.005182
# new_tests_smoothed_per_thousand                          0.351643
# positive_rate                                            0.353905
# tests_per_case                                          -0.023361
# total_vaccinations                                      -0.053649
# people_vaccinated                                       -0.054122
# people_fully_vaccinated                                 -0.050755
# total_boosters                                          -0.056624
# new_vaccinations                                        -0.068818
# new_vaccinations_smoothed                               -0.019294
# total_vaccinations_per_hundred                           0.242169
# people_vaccinated_per_hundred                            0.219263
# people_fully_vaccinated_per_hundred                      0.229034
# total_boosters_per_hundred                               0.228101
# new_vaccinations_smoothed_per_million                    0.051305
# new_people_vaccinated_smoothed                          -0.021950
# new_people_vaccinated_smoothed_per_hundred              -0.022178
# stringency_index                                        -0.039082
# population_density                                       0.018102
# median_age                                               0.220857
# aged_65_older                                            0.216966
# aged_70_older                                            0.217956
# gdp_per_capita                                           0.132520
# extreme_poverty                                         -0.137888
# cardiovasc_death_rate                                   -0.106904
# diabetes_prevalence                                      0.039855
# female_smokers                                           0.171899
# male_smokers                                             0.020389
# handwashing_facilities                                   0.110798
# hospital_beds_per_thousand                               0.115204
# life_expectancy                                          0.107051
# human_development_index                                  0.204432
# population                                              -0.018859
# excess_mortality_cumulative_absolute                    -0.026457
# excess_mortality_cumulative                              0.015256
# excess_mortality                                         0.109332
# excess_mortality_cumulative_per_million                  0.074166
#
#                                             new_cases_smoothed_per_million  \
# total_cases                                                       0.019262
# new_cases                                                         0.076962
# new_cases_smoothed                                                0.079204
# total_deaths                                                      0.004377
# new_deaths                                                        0.008945
# new_deaths_smoothed                                               0.008606
# total_cases_per_million                                           0.310826
# new_cases_per_million                                             0.600007
# new_cases_smoothed_per_million                                    1.000000
# total_deaths_per_million                                          0.180356
# new_deaths_per_million                                            0.181410
# new_deaths_smoothed_per_million                                   0.283380
# reproduction_rate                                                 0.097224
# icu_patients                                                      0.040745
# icu_patients_per_million                                          0.170095
# hosp_patients                                                     0.077218
# hosp_patients_per_million                                         0.302216
# weekly_icu_admissions                                             0.165484
# weekly_icu_admissions_per_million                                 0.046567
# weekly_hosp_admissions                                            0.092966
# weekly_hosp_admissions_per_million                                0.103222
# total_tests                                                       0.085934
# new_tests                                                         0.118529
# total_tests_per_thousand                                          0.398346
# new_tests_per_thousand                                            0.352696
# new_tests_smoothed                                               -0.006636
# new_tests_smoothed_per_thousand                                   0.406306
# positive_rate                                                     0.420806
# tests_per_case                                                   -0.027179
# total_vaccinations                                               -0.060945
# people_vaccinated                                                -0.061712
# people_fully_vaccinated                                          -0.057798
# total_boosters                                                   -0.063901
# new_vaccinations                                                 -0.080531
# new_vaccinations_smoothed                                        -0.030635
# total_vaccinations_per_hundred                                    0.278984
# people_vaccinated_per_hundred                                     0.250893
# people_fully_vaccinated_per_hundred                               0.262276
# total_boosters_per_hundred                                        0.264960
# new_vaccinations_smoothed_per_million                             0.077061
# new_people_vaccinated_smoothed                                   -0.034642
# new_people_vaccinated_smoothed_per_hundred                       -0.032671
# stringency_index                                                 -0.052583
# population_density                                                0.024587
# median_age                                                        0.273235
# aged_65_older                                                     0.269032
# aged_70_older                                                     0.269809
# gdp_per_capita                                                    0.178835
# extreme_poverty                                                  -0.180680
# cardiovasc_death_rate                                            -0.136965
# diabetes_prevalence                                               0.054365
# female_smokers                                                    0.220377
# male_smokers                                                      0.026165
# handwashing_facilities                                            0.147434
# hospital_beds_per_thousand                                        0.149706
# life_expectancy                                                   0.180738
# human_development_index                                           0.260507
# population                                                       -0.031738
# excess_mortality_cumulative_absolute                             -0.023240
# excess_mortality_cumulative                                      -0.015816
# excess_mortality                                                  0.099917
# excess_mortality_cumulative_per_million                           0.087317
#
#                                             total_deaths_per_million  \
# total_cases                                                 0.117472
# new_cases                                                   0.071847
# new_cases_smoothed                                          0.074411
# total_deaths                                                0.127753
# new_deaths                                                  0.029044
# new_deaths_smoothed                                         0.030630
# total_cases_per_million                                     0.598654
# new_cases_per_million                                       0.116564
# new_cases_smoothed_per_million                              0.180356
# total_deaths_per_million                                    1.000000
# new_deaths_per_million                                      0.140523
# new_deaths_smoothed_per_million                             0.246371
# reproduction_rate                                           0.011348
# icu_patients                                                0.070744
# icu_patients_per_million                                    0.144695
# hosp_patients                                               0.122683
# hosp_patients_per_million                                   0.212324
# weekly_icu_admissions                                       0.029882
# weekly_icu_admissions_per_million                           0.109872
# weekly_hosp_admissions                                      0.136384
# weekly_hosp_admissions_per_million                          0.116893
# total_tests                                                 0.191172
# new_tests                                                   0.143543
# total_tests_per_thousand                                    0.270372
# new_tests_per_thousand                                      0.137505
# new_tests_smoothed                                         -0.037332
# new_tests_smoothed_per_thousand                             0.121604
# positive_rate                                               0.195049
# tests_per_case                                             -0.055949
# total_vaccinations                                         -0.071577
# people_vaccinated                                          -0.068054
# people_fully_vaccinated                                    -0.071170
# total_boosters                                             -0.061970
# new_vaccinations                                           -0.129908
# new_vaccinations_smoothed                                  -0.041835
# total_vaccinations_per_hundred                              0.302499
# people_vaccinated_per_hundred                               0.348658
# people_fully_vaccinated_per_hundred                         0.295654
# total_boosters_per_hundred                                  0.243499
# new_vaccinations_smoothed_per_million                       0.015539
# new_people_vaccinated_smoothed                             -0.046594
# new_people_vaccinated_smoothed_per_hundred                 -0.059663
# stringency_index                                           -0.271997
# population_density                                         -0.009374
# median_age                                                  0.432360
# aged_65_older                                               0.430591
# aged_70_older                                               0.428615
# gdp_per_capita                                              0.159717
# extreme_poverty                                            -0.360528
# cardiovasc_death_rate                                      -0.119467
# diabetes_prevalence                                         0.028230
# female_smokers                                              0.427284
# male_smokers                                                0.117503
# handwashing_facilities                                      0.427924
# hospital_beds_per_thousand                                  0.239076
# life_expectancy                                             0.346949
# human_development_index                                     0.400378
# population                                                 -0.051804
# excess_mortality_cumulative_absolute                        0.316970
# excess_mortality_cumulative                                 0.552841
# excess_mortality                                            0.053380
# excess_mortality_cumulative_per_million                     0.839031
#
#                                             new_deaths_per_million  \
# total_cases                                              -0.002134
# new_cases                                                 0.027721
# new_cases_smoothed                                        0.024378
# total_deaths                                              0.005605
# new_deaths                                                0.065524
# new_deaths_smoothed                                       0.056646
# total_cases_per_million                                   0.049797
# new_cases_per_million                                     0.184577
# new_cases_smoothed_per_million                            0.181410
# total_deaths_per_million                                  0.140523
# new_deaths_per_million                                    1.000000
# new_deaths_smoothed_per_million                           0.638232
# reproduction_rate                                         0.045578
# icu_patients                                              0.213966
# icu_patients_per_million                                  0.664593
# hosp_patients                                             0.226905
# hosp_patients_per_million                                 0.725111
# weekly_icu_admissions                                     0.362564
# weekly_icu_admissions_per_million                         0.282088
# weekly_hosp_admissions                                    0.264898
# weekly_hosp_admissions_per_million                        0.240514
# total_tests                                               0.007757
# new_tests                                                 0.054214
# total_tests_per_thousand                                  0.036343
# new_tests_per_thousand                                    0.098048
# new_tests_smoothed                                       -0.026665
# new_tests_smoothed_per_thousand                           0.102315
# positive_rate                                             0.315184
# tests_per_case                                           -0.034694
# total_vaccinations                                       -0.068293
# people_vaccinated                                        -0.063920
# people_fully_vaccinated                                  -0.070112
# total_boosters                                           -0.081798
# new_vaccinations                                         -0.049706
# new_vaccinations_smoothed                                -0.012152
# total_vaccinations_per_hundred                           -0.119407
# people_vaccinated_per_hundred                            -0.111191
# people_fully_vaccinated_per_hundred                      -0.129222
# total_boosters_per_hundred                               -0.083280
# new_vaccinations_smoothed_per_million                     0.101430
# new_people_vaccinated_smoothed                           -0.006738
# new_people_vaccinated_smoothed_per_hundred                0.114490
# stringency_index                                          0.122065
# population_density                                        0.002803
# median_age                                                0.181540
# aged_65_older                                             0.178766
# aged_70_older                                             0.176926
# gdp_per_capita                                            0.062491
# extreme_poverty                                          -0.153170
# cardiovasc_death_rate                                    -0.036173
# diabetes_prevalence                                       0.024695
# female_smokers                                            0.181033
# male_smokers                                              0.059012
# handwashing_facilities                                    0.228480
# hospital_beds_per_thousand                                0.107631
# life_expectancy                                           0.112955
# human_development_index                                   0.165905
# population                                               -0.020456
# excess_mortality_cumulative_absolute                     -0.017393
# excess_mortality_cumulative                               0.179660
# excess_mortality                                          0.507619
# excess_mortality_cumulative_per_million                   0.099279
#
#                                             new_deaths_smoothed_per_million  \
# total_cases                                                       -0.002758
# new_cases                                                          0.038517
# new_cases_smoothed                                                 0.040885
# total_deaths                                                       0.010745
# new_deaths                                                         0.094107
# new_deaths_smoothed                                                0.096416
# total_cases_per_million                                            0.083836
# new_cases_per_million                                              0.169499
# new_cases_smoothed_per_million                                     0.283380
# total_deaths_per_million                                           0.246371
# new_deaths_per_million                                             0.638232
# new_deaths_smoothed_per_million                                    1.000000
# reproduction_rate                                                  0.059364
# icu_patients                                                       0.242954
# icu_patients_per_million                                           0.770287
# hosp_patients                                                      0.259480
# hosp_patients_per_million                                          0.835400
# weekly_icu_admissions                                              0.427990
# weekly_icu_admissions_per_million                                  0.469591
# weekly_hosp_admissions                                             0.284917
# weekly_hosp_admissions_per_million                                 0.372785
# total_tests                                                        0.012028
# new_tests                                                          0.051804
# total_tests_per_thousand                                           0.045868
# new_tests_per_thousand                                             0.104222
# new_tests_smoothed                                                -0.032511
# new_tests_smoothed_per_thousand                                    0.119688
# positive_rate                                                      0.366376
# tests_per_case                                                    -0.042079
# total_vaccinations                                                -0.091086
# people_vaccinated                                                 -0.085936
# people_fully_vaccinated                                           -0.097050
# total_boosters                                                    -0.100867
# new_vaccinations                                                  -0.067703
# new_vaccinations_smoothed                                         -0.018743
# total_vaccinations_per_hundred                                    -0.159913
# people_vaccinated_per_hundred                                     -0.149976
# people_fully_vaccinated_per_hundred                               -0.181155
# total_boosters_per_hundred                                        -0.104006
# new_vaccinations_smoothed_per_million                              0.159464
# new_people_vaccinated_smoothed                                    -0.010188
# new_people_vaccinated_smoothed_per_hundred                         0.175325
# stringency_index                                                   0.211631
# population_density                                                 0.004496
# median_age                                                         0.295851
# aged_65_older                                                      0.292807
# aged_70_older                                                      0.290010
# gdp_per_capita                                                     0.103510
# extreme_poverty                                                   -0.255048
# cardiovasc_death_rate                                             -0.058047
# diabetes_prevalence                                                0.039276
# female_smokers                                                     0.299576
# male_smokers                                                       0.099341
# handwashing_facilities                                             0.305812
# hospital_beds_per_thousand                                         0.176719
# life_expectancy                                                    0.194579
# human_development_index                                            0.266925
# population                                                        -0.034489
# excess_mortality_cumulative_absolute                               0.033340
# excess_mortality_cumulative                                        0.235432
# excess_mortality                                                   0.642389
# excess_mortality_cumulative_per_million                            0.188651
#
#                                             reproduction_rate  icu_patients  \
# total_cases                                          0.015249      0.427364
# new_cases                                            0.034652      0.566308
# new_cases_smoothed                                   0.029602      0.620019
# total_deaths                                         0.020758      0.572833
# new_deaths                                           0.027227      0.846498
# new_deaths_smoothed                                  0.025673      0.910996
# total_cases_per_million                             -0.035956     -0.060391
# new_cases_per_million                                0.099997      0.035675
# new_cases_smoothed_per_million                       0.097224      0.040745
# total_deaths_per_million                             0.011348      0.070744
# new_deaths_per_million                               0.045578      0.213966
# new_deaths_smoothed_per_million                      0.059364      0.242954
# reproduction_rate                                    1.000000     -0.046534
# icu_patients                                        -0.046534      1.000000
# icu_patients_per_million                            -0.114093      0.389600
# hosp_patients                                       -0.053375      0.943143
# hosp_patients_per_million                           -0.114003      0.155563
# weekly_icu_admissions                               -0.021596      0.824685
# weekly_icu_admissions_per_million                   -0.041794      0.134438
# weekly_hosp_admissions                              -0.031706      0.921492
# weekly_hosp_admissions_per_million                  -0.026944      0.064681
# total_tests                                         -0.021405      0.547618
# new_tests                                            0.004007      0.707243
# total_tests_per_thousand                            -0.019145     -0.072695
# new_tests_per_thousand                               0.025903     -0.047832
# new_tests_smoothed                                   0.016217      0.735279
# new_tests_smoothed_per_thousand                      0.047838     -0.054210
# positive_rate                                        0.086863      0.066762
# tests_per_case                                      -0.003637     -0.065001
# total_vaccinations                                   0.009880      0.451436
# people_vaccinated                                    0.002252      0.514086
# people_fully_vaccinated                              0.003915      0.486158
# total_boosters                                      -0.008480      0.230545
# new_vaccinations                                     0.011863      0.550949
# new_vaccinations_smoothed                            0.038131      0.588373
# total_vaccinations_per_hundred                       0.022647     -0.143495
# people_vaccinated_per_hundred                        0.025450     -0.127837
# people_fully_vaccinated_per_hundred                  0.044892     -0.127284
# total_boosters_per_hundred                          -0.029746     -0.185123
# new_vaccinations_smoothed_per_million                0.139534      0.055011
# new_people_vaccinated_smoothed                       0.031054      0.549205
# new_people_vaccinated_smoothed_per_hundred           0.066195      0.099823
# stringency_index                                     0.263538      0.188863
# population_density                                   0.028780     -0.110015
# median_age                                           0.231471     -0.031288
# aged_65_older                                        0.207128     -0.004747
# aged_70_older                                        0.202114      0.000030
# gdp_per_capita                                       0.159214      0.105093
# extreme_poverty                                     -0.207919      0.007956
# cardiovasc_death_rate                               -0.124092     -0.074522
# diabetes_prevalence                                 -0.024124      0.170508
# female_smokers                                       0.129147      0.032962
# male_smokers                                        -0.012122     -0.089808
# handwashing_facilities                               0.167342     -0.342258
# hospital_beds_per_thousand                           0.096485     -0.053630
# life_expectancy                                      0.233263     -0.042454
# human_development_index                              0.226595      0.077186
# population                                           0.042184      0.747902
# excess_mortality_cumulative_absolute                -0.057222      0.610931
# excess_mortality_cumulative                         -0.133482      0.186898
# excess_mortality                                    -0.057072      0.175160
# excess_mortality_cumulative_per_million             -0.136969      0.049785
#
#                                             icu_patients_per_million  \
# total_cases                                                -0.009693
# new_cases                                                   0.141977
# new_cases_smoothed                                          0.158048
# total_deaths                                                0.058951
# new_deaths                                                  0.304960
# new_deaths_smoothed                                         0.328663
# total_cases_per_million                                    -0.127097
# ...
# new_people_vaccinated_smoothed_per_hundred                             -0.050935
# stringency_index                                                       -0.063841
# population_density                                                     -0.057441
# median_age                                                             -0.154142
# aged_65_older                                                          -0.147530
# aged_70_older                                                          -0.145590
# gdp_per_capita                                                         -0.056528
# extreme_poverty                                                         0.135583
# cardiovasc_death_rate                                                  -0.006260
# diabetes_prevalence                                                     0.145097
# female_smokers                                                         -0.117327
# male_smokers                                                           -0.092140
# handwashing_facilities                                                 -0.032367
# hospital_beds_per_thousand                                             -0.144168
# life_expectancy                                                        -0.194425
# human_development_index                                                -0.112262
# population                                                              0.746033
# excess_mortality_cumulative_absolute                                    1.000000
# excess_mortality_cumulative                                             0.362056
# excess_mortality                                                        0.069834
# excess_mortality_cumulative_per_million                                 0.391607
#
#                                             excess_mortality_cumulative  \
# total_cases                                                    0.093883
# new_cases                                                      0.049482
# new_cases_smoothed                                             0.040194
# total_deaths                                                   0.280627
# new_deaths                                                     0.224177
# new_deaths_smoothed                                            0.203424
# total_cases_per_million                                        0.078718
# new_cases_per_million                                          0.015256
# new_cases_smoothed_per_million                                -0.015816
# total_deaths_per_million                                       0.552841
# new_deaths_per_million                                         0.179660
# new_deaths_smoothed_per_million                                0.235432
# reproduction_rate                                             -0.133482
# icu_patients                                                   0.186898
# icu_patients_per_million                                       0.343792
# hosp_patients                                                  0.246413
# hosp_patients_per_million                                      0.371650
# weekly_icu_admissions                                          0.314677
# weekly_icu_admissions_per_million                              0.322385
# weekly_hosp_admissions                                         0.298740
# weekly_hosp_admissions_per_million                             0.261515
# total_tests                                                    0.050605
# new_tests                                                      0.061118
# total_tests_per_thousand                                      -0.036120
# new_tests_per_thousand                                        -0.027842
# new_tests_smoothed                                             0.038273
# new_tests_smoothed_per_thousand                               -0.061069
# positive_rate                                                  0.250700
# tests_per_case                                                -0.076484
# total_vaccinations                                             0.047200
# people_vaccinated                                              0.075531
# people_fully_vaccinated                                        0.052834
# total_boosters                                                 0.056454
# new_vaccinations                                               0.153859
# new_vaccinations_smoothed                                      0.118817
# total_vaccinations_per_hundred                                -0.155868
# people_vaccinated_per_hundred                                 -0.135967
# people_fully_vaccinated_per_hundred                           -0.139134
# total_boosters_per_hundred                                    -0.014887
# new_vaccinations_smoothed_per_million                         -0.074464
# new_people_vaccinated_smoothed                                 0.121255
# new_people_vaccinated_smoothed_per_hundred                    -0.029786
# stringency_index                                               0.046843
# population_density                                            -0.052817
# median_age                                                    -0.385511
# aged_65_older                                                 -0.389613
# aged_70_older                                                 -0.370616
# gdp_per_capita                                                -0.358041
# extreme_poverty                                                0.261652
# cardiovasc_death_rate                                          0.075100
# diabetes_prevalence                                            0.053337
# female_smokers                                                -0.272357
# male_smokers                                                  -0.045681
# handwashing_facilities                                        -0.005269
# hospital_beds_per_thousand                                    -0.258237
# life_expectancy                                               -0.304974
# human_development_index                                       -0.445579
# population                                                     0.162907
# excess_mortality_cumulative_absolute                           0.362056
# excess_mortality_cumulative                                    1.000000
# excess_mortality                                               0.431281
# excess_mortality_cumulative_per_million                        0.693282
#
#                                             excess_mortality  \
# total_cases                                        -0.022547
# new_cases                                           0.083522
# new_cases_smoothed                                  0.064064
# total_deaths                                        0.016416
# new_deaths                                          0.353579
# new_deaths_smoothed                                 0.286932
# total_cases_per_million                            -0.055450
# new_cases_per_million                               0.109332
# new_cases_smoothed_per_million                      0.099917
# total_deaths_per_million                            0.053380
# new_deaths_per_million                              0.507619
# new_deaths_smoothed_per_million                     0.642389
# reproduction_rate                                  -0.057072
# icu_patients                                        0.175160
# icu_patients_per_million                            0.583081
# hosp_patients                                       0.226743
# hosp_patients_per_million                           0.687650
# weekly_icu_admissions                               0.393889
# weekly_icu_admissions_per_million                   0.467565
# weekly_hosp_admissions                              0.296706
# weekly_hosp_admissions_per_million                  0.406170
# total_tests                                        -0.039540
# new_tests                                          -0.000047
# total_tests_per_thousand                           -0.055273
# new_tests_per_thousand                              0.012153
# new_tests_smoothed                                 -0.004976
# new_tests_smoothed_per_thousand                    -0.007679
# positive_rate                                       0.385032
# tests_per_case                                     -0.062523
# total_vaccinations                                 -0.070128
# people_vaccinated                                  -0.051955
# people_fully_vaccinated                            -0.062469
# total_boosters                                     -0.048648
# new_vaccinations                                    0.040678
# new_vaccinations_smoothed                           0.027019
# total_vaccinations_per_hundred                     -0.217814
# people_vaccinated_per_hundred                      -0.218201
# people_fully_vaccinated_per_hundred                -0.198920
# total_boosters_per_hundred                         -0.061808
# new_vaccinations_smoothed_per_million               0.040150
# new_people_vaccinated_smoothed                      0.052613
# new_people_vaccinated_smoothed_per_hundred          0.066940
# stringency_index                                    0.244530
# population_density                                 -0.022766
# median_age                                         -0.188884
# aged_65_older                                      -0.200700
# aged_70_older                                      -0.193264
# gdp_per_capita                                     -0.219857
# extreme_poverty                                     0.135145
# cardiovasc_death_rate                               0.128158
# diabetes_prevalence                                 0.072622
# female_smokers                                     -0.100375
# male_smokers                                        0.065002
# handwashing_facilities                             -0.010683
# hospital_beds_per_thousand                         -0.095258
# life_expectancy                                    -0.204865
# human_development_index                            -0.268987
# population                                          0.047663
# excess_mortality_cumulative_absolute                0.069834
# excess_mortality_cumulative                         0.431281
# excess_mortality                                    1.000000
# excess_mortality_cumulative_per_million             0.190704
#
#                                             excess_mortality_cumulative_per_million
# total_cases                                                                0.189320
# new_cases                                                                  0.054802
# new_cases_smoothed                                                         0.071633
# total_deaths                                                               0.303454
# new_deaths                                                                 0.067323
# new_deaths_smoothed                                                        0.091433
# total_cases_per_million                                                    0.375051
# new_cases_per_million                                                      0.074166
# new_cases_smoothed_per_million                                             0.087317
# total_deaths_per_million                                                   0.839031
# new_deaths_per_million                                                     0.099279
# new_deaths_smoothed_per_million                                            0.188651
# reproduction_rate                                                         -0.136969
# icu_patients                                                               0.049785
# icu_patients_per_million                                                   0.167652
# hosp_patients                                                              0.102701
# hosp_patients_per_million                                                  0.317293
# weekly_icu_admissions                                                      0.301654
# weekly_icu_admissions_per_million                                          0.402327
# weekly_hosp_admissions                                                     0.226373
# weekly_hosp_admissions_per_million                                         0.360916
# total_tests                                                                0.165484
# new_tests                                                                  0.107246
# total_tests_per_thousand                                                   0.133969
# new_tests_per_thousand                                                     0.019173
# new_tests_smoothed                                                         0.082574
# new_tests_smoothed_per_thousand                                            0.003008
# positive_rate                                                              0.221421
# tests_per_case                                                            -0.077039
# total_vaccinations                                                         0.100325
# people_vaccinated                                                          0.114189
# people_fully_vaccinated                                                    0.096325
# total_boosters                                                             0.098635
# new_vaccinations                                                           0.043529
# new_vaccinations_smoothed                                                  0.013844
# total_vaccinations_per_hundred                                             0.001078
# people_vaccinated_per_hundred                                              0.029283
# people_fully_vaccinated_per_hundred                                        0.039742
# total_boosters_per_hundred                                                 0.037255
# new_vaccinations_smoothed_per_million                                     -0.232133
# new_people_vaccinated_smoothed                                            -0.006474
# new_people_vaccinated_smoothed_per_hundred                                -0.206362
# stringency_index                                                          -0.294438
# population_density                                                        -0.045728
# median_age                                                                -0.022156
# aged_65_older                                                             -0.024048
# aged_70_older                                                             -0.017369
# gdp_per_capita                                                            -0.319855
# extreme_poverty                                                            0.198075
# cardiovasc_death_rate                                                      0.299610
# diabetes_prevalence                                                       -0.061718
# female_smokers                                                             0.062062
# male_smokers                                                               0.210842
# handwashing_facilities                                                     0.007701
# hospital_beds_per_thousand                                                 0.061736
# life_expectancy                                                           -0.300254
# human_development_index                                                   -0.271307
# population                                                                 0.099475
# excess_mortality_cumulative_absolute                                       0.391607
# excess_mortality_cumulative                                                0.693282
# excess_mortality                                                           0.190704
# excess_mortality_cumulative_per_million                                    1.000000

# %% [markdown]
# # A. Cleaning Data

# %% [markdown]
# ## Select variables related to 'new_cases' based on the correlation(over 0.5) of it

# %%
corr = data.corr()
# Out:
# /var/folders/3z/92v05ntj4hnc_xkhx758n9r40000gn/T/ipykernel_34707/1351907255.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()

# %%
corr = corr['new_cases']
corr_var=corr>=0.5
newcases_corr = corr[corr_var]

# %%
filtered_columns = pd.DataFrame(newcases_corr[:,]).index

# %%
filtered_columns
# Out:
# Index(['total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'icu_patients', 'hosp_patients',
#        'weekly_hosp_admissions', 'new_tests', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'new_vaccinations_smoothed', 'population'],
#       dtype='object')

# %% [markdown]
# ## Add `continent` and `date`, which have no correlation since they are categorical variables.

# %%
data = data[data.columns[data.columns.isin(filtered_columns | ['continent', 'date'])]]
# Out:
# /var/folders/3z/92v05ntj4hnc_xkhx758n9r40000gn/T/ipykernel_34707/2053250998.py:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   data = data[data.columns[data.columns.isin(filtered_columns | ['continent', 'date'])]]

# %%
data.head(5)
# Out:
#   continent        date  total_cases  new_cases  new_cases_smoothed  \
# 0      Asia  2020-02-24          5.0        5.0                 NaN
# 1      Asia  2020-02-25          5.0        0.0                 NaN
# 2      Asia  2020-02-26          5.0        0.0                 NaN
# 3      Asia  2020-02-27          5.0        0.0                 NaN
# 4      Asia  2020-02-28          5.0        0.0                 NaN
#
#    total_deaths  new_deaths  new_deaths_smoothed  icu_patients  hosp_patients  \
# 0           NaN         NaN                  NaN           NaN            NaN
# 1           NaN         NaN                  NaN           NaN            NaN
# 2           NaN         NaN                  NaN           NaN            NaN
# 3           NaN         NaN                  NaN           NaN            NaN
# 4           NaN         NaN                  NaN           NaN            NaN
#
#    weekly_hosp_admissions  new_tests  total_vaccinations  people_vaccinated  \
# 0                     NaN        NaN                 NaN                NaN
# 1                     NaN        NaN                 NaN                NaN
# 2                     NaN        NaN                 NaN                NaN
# 3                     NaN        NaN                 NaN                NaN
# 4                     NaN        NaN                 NaN                NaN
#
#    people_fully_vaccinated  new_vaccinations_smoothed  population
# 0                      NaN                        NaN  41128772.0
# 1                      NaN                        NaN  41128772.0
# 2                      NaN                        NaN  41128772.0
# 3                      NaN                        NaN  41128772.0
# 4                      NaN                        NaN  41128772.0

# %% [markdown]
# ## Drop the columns if it is less than the minimum thresh (60%)

# %%
def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
missing_values_table(data)
# Out:
# Your selected dataframe has 17 columns.
# There are 16 columns that have missing values.
#                            Missing Values  % of Total Values
# weekly_hosp_admissions             219059               92.0
# icu_patients                       206051               86.5
# hosp_patients                      202093               84.8
# people_fully_vaccinated            176011               73.9
# people_vaccinated                  173366               72.8
# total_vaccinations                 170363               71.5
# new_tests                          162831               68.3
# new_vaccinations_smoothed           97807               41.1
# new_deaths_smoothed                 34063               14.3
# new_deaths                          32879               13.8
# total_deaths                        32795               13.8
# new_cases_smoothed                  14994                6.3
# new_cases                           13795                5.8
# total_cases                         13459                5.6
# continent                           13427                5.6
# population                           1025                0.4

# %%
perc = 60.0 # N %
min_count =  int(((100-perc)/100)*data.shape[0] + 1)
data = data.dropna( axis=1, 
                thresh=min_count)

# %% [markdown]
# ## Remove outliers

# %%
def cap_data(df):
    for col in df.columns:
        print("capping the ",col)
        if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64')):
            percentiles = df[col].quantile([0.01,0.99]).values
            df[col][df[col] <= percentiles[0]] = percentiles[0]
            df[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            df[col]=df[col]
    return df

final_df=cap_data(data)
# Out:
# capping the  continent
# capping the  date
# capping the  total_cases
# capping the  new_cases
# capping the  new_cases_smoothed
# capping the  total_deaths
# capping the  new_deaths
# capping the  new_deaths_smoothed
# capping the  new_vaccinations_smoothed
# capping the  population
# /var/folders/3z/92v05ntj4hnc_xkhx758n9r40000gn/T/ipykernel_34707/2495983979.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][df[col] <= percentiles[0]] = percentiles[0]
# /var/folders/3z/92v05ntj4hnc_xkhx758n9r40000gn/T/ipykernel_34707/2495983979.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][df[col] >= percentiles[1]] = percentiles[1]

# %% [markdown]
# ## Data type changes for `date` and one-hot encode for the categorical variables

# %%
final_df['date']= pd.to_datetime(final_df['date'])
final_df['year'] = final_df['date'].dt.year
final_df['month'] = final_df['date'].dt.month

# %%
final_df = final_df.drop(['date'], axis=1)

# %%
final_df['year'] = pd.Categorical(final_df['year'])
final_df['month'] = pd.Categorical(final_df['month'])

# %%
final_df.head(5)
# Out:
#   continent  total_cases  new_cases  new_cases_smoothed  total_deaths  \
# 0      Asia          5.0        5.0                 NaN           NaN
# 1      Asia          5.0        0.0                 NaN           NaN
# 2      Asia          5.0        0.0                 NaN           NaN
# 3      Asia          5.0        0.0                 NaN           NaN
# 4      Asia          5.0        0.0                 NaN           NaN
#
#    new_deaths  new_deaths_smoothed  new_vaccinations_smoothed  population  \
# 0         NaN                  NaN                        NaN  41128772.0
# 1         NaN                  NaN                        NaN  41128772.0
# 2         NaN                  NaN                        NaN  41128772.0
# 3         NaN                  NaN                        NaN  41128772.0
# 4         NaN                  NaN                        NaN  41128772.0
#
#    year month
# 0  2020     2
# 1  2020     2
# 2  2020     2
# 3  2020     2
# 4  2020     2

# %%
# One-hot encode the data using pandas get_dummies
final_df = pd.get_dummies(final_df)

# %% [markdown]
# ## Remove rows including NA

# %%
final_df = final_df.dropna()

# %%
final_df.head(5)
# Out:
#      total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 365      55646.0       29.0              18.286        2435.0         2.0
# 366      55664.0       18.0              17.714        2436.0         1.0
# 367      55680.0       16.0              17.571        2438.0         2.0
# 368      55696.0       16.0              17.286        2442.0         4.0
# 369      55707.0       11.0              18.143        2443.0         1.0
#
#      new_deaths_smoothed  new_vaccinations_smoothed  population  \
# 365                1.000                     1367.0  41128772.0
# 366                1.143                     1367.0  41128772.0
# 367                1.143                     1367.0  41128772.0
# 368                1.714                     1367.0  41128772.0
# 369                1.857                     1367.0  41128772.0
#
#      continent_Africa  continent_Asia  continent_Europe  \
# 365                 0               1                 0
# 366                 0               1                 0
# 367                 0               1                 0
# 368                 0               1                 0
# 369                 0               1                 0
#
#      continent_North America  continent_Oceania  continent_South America  \
# 365                        0                  0                        0
# 366                        0                  0                        0
# 367                        0                  0                        0
# 368                        0                  0                        0
# 369                        0                  0                        0
#
#      year_2020  year_2021  year_2022  month_1  month_2  month_3  month_4  \
# 365          0          1          0        0        1        0        0
# 366          0          1          0        0        1        0        0
# 367          0          1          0        0        1        0        0
# 368          0          1          0        0        1        0        0
# 369          0          1          0        0        1        0        0
#
#      month_5  month_6  month_7  month_8  month_9  month_10  month_11  month_12
# 365        0        0        0        0        0         0         0         0
# 366        0        0        0        0        0         0         0         0
# 367        0        0        0        0        0         0         0         0
# 368        0        0        0        0        0         0         0         0
# 369        0        0        0        0        0         0         0         0

# %% [markdown]
# # B. Modeling
# # 1. RandomForest
# ## Let's use the RandomForest to find important features for `new_cases`

# %%
features = final_df

# %%
list(features.columns)
# Out:
# ['total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'new_vaccinations_smoothed',
#  'population',
#  'continent_Africa',
#  'continent_Asia',
#  'continent_Europe',
#  'continent_North America',
#  'continent_Oceania',
#  'continent_South America',
#  'year_2020',
#  'year_2021',
#  'year_2022',
#  'month_1',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12']

# %%
# Use numpy to convert to arrays
# Labels are the values we want to predict
y = np.array(features['new_cases'])
# Remove the labels from the features
# axis 1 refers to the columns
x = features.drop(['new_cases', 'new_cases_smoothed'], axis = 1)
#features = features.iloc[:, np.r_[0, 3:9]]

# Saving feature names for later use
feature_list = list(x.columns)
# Convert to numpy array
#features = np.array(x)

# %%
feature_list
# Out:
# ['total_cases',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'new_vaccinations_smoothed',
#  'population',
#  'continent_Africa',
#  'continent_Asia',
#  'continent_Europe',
#  'continent_North America',
#  'continent_Oceania',
#  'continent_South America',
#  'year_2020',
#  'year_2021',
#  'year_2022',
#  'month_1',
#  'month_2',
#  'month_3',
#  'month_4',
#  'month_5',
#  'month_6',
#  'month_7',
#  'month_8',
#  'month_9',
#  'month_10',
#  'month_11',
#  'month_12']

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import scale
x = scale(x)
y = scale(y)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.30)

# %%
from sklearn import set_config
from sklearn.ensemble import RandomForestRegressor

set_config(print_changed_only=False)
rfr = RandomForestRegressor(n_estimators = 100, random_state = 0)
print(rfr)

rfr.fit(xtrain, ytrain)

score = rfr.score(xtrain, ytrain)
print("R-squared:", score)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='squared_error',
#                       max_depth=None, max_features=1.0, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)
# R-squared: 0.9961200927633469

# %% [markdown]
# ## After using 100 regression trees, we got 99 R-square, which seems like overfitting.
# ## Let's check error rate and prediction by the plot

# %%
from sklearn.metrics import mean_squared_error

ypred = rfr.predict(xtest)

mse = mean_squared_error(ytest, ypred)
print("MSE: ", mse)
print("RMSE: ", mse*(1/2.0))
# Out:
# MSE:  0.026665057065944707
# RMSE:  0.013332528532972353

# %%
x_ax = range(len(ytest))
plt.plot(x_ax, ytest, linewidth=1, label="original")
plt.plot(x_ax, ypred, linewidth=1.1, label="predicted")
plt.title("y-test and y-predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Let's check important features for `new_cases`

# %%
rfr.feature_importances_
# Out:
# array([1.89009628e-01, 3.43596392e-02, 2.32870288e-01, 4.59151717e-01,
#        2.09972515e-02, 1.89454449e-02, 1.83526375e-05, 6.04067968e-04,
#        6.89333836e-04, 1.05294059e-03, 2.33807790e-04, 3.06434767e-04,
#        4.81843365e-05, 3.27219949e-03, 1.61900993e-02, 8.88929536e-03,
#        1.23913933e-03, 2.41150121e-03, 1.12315088e-03, 6.64037117e-04,
#        9.51649017e-04, 2.11826985e-03, 1.20784459e-03, 5.97570145e-04,
#        7.09790936e-04, 5.99318932e-04, 1.73904267e-03])

# %%
feature_list = np.asarray(feature_list)
feature_list
# Out:
# array(['total_cases', 'total_deaths', 'new_deaths', 'new_deaths_smoothed',
#        'new_vaccinations_smoothed', 'population', 'continent_Africa',
#        'continent_Asia', 'continent_Europe', 'continent_North America',
#        'continent_Oceania', 'continent_South America', 'year_2020',
#        'year_2021', 'year_2022', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'month_12'], dtype='<U25')

# %%
sorted_idx = rfr.feature_importances_.argsort()
plt.barh(feature_list[sorted_idx], rfr.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## `new_deaths`, `new_deaths_smoothed`, `total_cases` seems like strong predictors, and `new_vaccinations_smoothed`, `population` show slight importances.

# %% [markdown]
# ## Let's build the multiple linear regression by these predictors, since the randomforrest is overfitting

# %% [markdown]
# # 2. Multiple Linear regression

# %%
X = final_df[["new_deaths", "new_deaths_smoothed", "total_cases", "total_deaths", "new_vaccinations_smoothed", "population"]]
X1 = final_df[["new_deaths", "new_deaths_smoothed", "total_cases"]]
Y = final_df[["new_cases"]]

# %% [markdown]
# ## Exploring features

# %%
plt.scatter(X["new_deaths"],Y)
plt.xlabel("new_deaths")
plt.ylabel("new_cases")
# Out:
# Text(0, 0.5, 'new_cases')

# %%
plt.scatter(X["new_deaths_smoothed"],Y)
plt.xlabel("new_deaths_smoothed")
plt.ylabel("new_cases")
# Out:
# Text(0, 0.5, 'new_cases')

# %%
plt.scatter(X["total_cases"],Y)
plt.xlabel("total_cases")
plt.ylabel("new_cases")
# Out:
# Text(0, 0.5, 'new_cases')

# %%
plt.scatter(X["total_deaths"],Y)
plt.xlabel("total_deaths")
plt.ylabel("new_cases")
# Out:
# Text(0, 0.5, 'new_cases')

# %%
plt.scatter(X["new_vaccinations_smoothed"],Y)
plt.xlabel("new_vaccinations_smoothed")
plt.ylabel("new_cases")
# Out:
# Text(0, 0.5, 'new_cases')

# %%
plt.scatter(X["population"],Y)
plt.xlabel("population")
plt.ylabel("new_cases")
# Out:
# Text(0, 0.5, 'new_cases')

# %% [markdown]
# ## There are more small of population for the `new_cases` than large population

# %% [markdown]
# ## Divide into train/test dataset

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X1, Y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Normalization

# %%
from sklearn import preprocessing
x_scaler = preprocessing.StandardScaler().fit(X_train)
X_train = x_scaler.transform(X_train)

y_scaler = preprocessing.StandardScaler().fit(y_train)
y_train = y_scaler.transform(y_train)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                  normalize='deprecated', positive=False)

# %%
print (f"Model coeficients for features {X1.columns} are {model.coef_}")
# Out:
# Model coeficients for features Index(['new_deaths', 'new_deaths_smoothed', 'total_cases'], dtype='object') are [[ 0.52899128 -0.02082223  0.47397942]]

# %%
y_pred= model.predict(X_train)

plt.subplot(2, 3, 1)
plt.scatter(X_train[:, 0], y_train)
plt.plot([min(X_train[:, 0]), max(X_train[:, 0])], [min(y_pred), max(y_pred)], color="orange")
plt.xlabel("new_deaths")
plt.ylabel("new_cases")

plt.subplot(2, 3, 2)
plt.scatter(X_train[:, 1], y_train)
plt.scatter(X_train[:, 1],y_pred)
plt.xlabel("new_deaths_smoothed")
plt.ylabel("new_cases")

plt.subplot(2, 3, 3)
plt.scatter(X_train[:, 2], y_train)
plt.plot([min(X_train[:, 2]), max(X_train[:, 1])], [min(y_pred), max(y_pred)], color="orange")
plt.xlabel("total_cases")
plt.ylabel("new_cases")
# Out:
# Text(0, 0.5, 'new_cases')

# %% [markdown]
# ## Model Testing: Testing data

# %%
X_test = x_scaler.transform(X_test)
y_test = y_scaler.transform(y_test)
y_pred= model.predict(X_test)

# %%
MSE = metrics.mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(MSE)
pd.DataFrame([MSE, RMSE], index=['MSE', 'RMSE'], columns=['Metrics'])
# Out:
#        Metrics
# MSE   0.204232
# RMSE  0.451921

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_pred)
# Out:
# 0.7959330086919738

# %% [markdown]
# ## R-squared of the multiple linear regression is around 80, which seems not overfitting. Since  predictors are not very strong, it is expectable.

# %%
y_pred
# Out:
# array([[-0.25190222],
#        [-0.26769983],
#        [-0.24305113],
#        ...,
#        [-0.22746004],
#        [-0.12649364],
#        [ 0.64387483]])

# %%
y_pred = y_scaler.inverse_transform(y_pred)
y_pred
# Out:
# array([[ 1130.69639584],
#        [  427.79098343],
#        [ 1524.5205535 ],
#        ...,
#        [ 2218.23694911],
#        [ 6710.67819015],
#        [40987.77427709]])
